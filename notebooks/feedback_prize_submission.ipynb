# %%
import warnings
from kaggle_secrets import UserSecretsClient

warnings.filterwarnings("ignore")

user_secrets = UserSecretsClient()
github_auth_token = user_secrets.get_secret("github_auth_token")

# %%
import subprocess
import contextlib

with contextlib.redirect_stdout(None), contextlib.redirect_stderr(None):
    subprocess.run(["git", "clone", f"https://{github_auth_token}@github.com/kashperova/nlp-iasa.git"])

# %%
# !pip install /kaggle/input/transformers-package/transformers-4.49.0-py3-none-any.whl
# !pip install /kaggle/input/transformers-package/evaluate-0.4.3-py3-none-any.whl
# !pip install seqeval

# %%
# %cd nlp-iasa/src
# Out:
# /kaggle/working/nlp-iasa/src

# %%
from trainings.feedback_prize import run_inference
from IPython.display import Image, display

# %%
class Config:
    test_txt_path: str = "/kaggle/input/feedback-prize-2021/test"
    train_csv_path: str = "/kaggle/input/feedback-prize-2021/train.csv"
    checkpoint_path: str = "/kaggle/input/modern-bert-feedback-prize"
    max_length: int = 2048
    min_tokens: int = 4
    beam_size: int = 4

# %%
run_inference(
    test_txt_path=Config.test_txt_path,
    train_csv_path=Config.train_csv_path,
    checkpoint_path=Config.checkpoint_path,
    max_length=Config.max_length,
    min_tokens=Config.min_tokens,
    beam_size=Config.beam_size,
)
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
display(Image("../assets/submission_mb_screen.png"))

# %%
display(Image("../assets/submission_lf_screen.png"))
